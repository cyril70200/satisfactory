# %%
import json
from collections import defaultdict
import math

# Global constants
MAX_RECURSION_DEPTH = 6  # Default max recursion depth

def load_data():
    """Load the Satisfactory data from the JSON file."""
    with open("raw_data/data.json", 'r', encoding='utf-8') as file:
        return json.load(file)

def get_item_recipes(data, item_id):
    """Get all recipes that produce the given item."""
    recipes = []

    # First, validate that the item actually exists
    if item_id not in data.get('items', {}) and item_id not in data.get('resources', {}):
        print(f"Warning: Item '{item_id}' does not exist in the data!")
        return []

    if item_id in data.get('resources', {}):
        print(f"Item '{item_id}' is a resource, not a recipe product.")
        return

    # Find recipes that produce this item
    for recipe_id, recipe_data in data['recipes'].items():
        if not recipe_data.get('products'):
            continue

        for product in recipe_data.get('products', []):
            if not isinstance(product, dict):
                continue

            product_item = product.get('item')
            if product_item == item_id:
                for ingredient in recipe_data.get('ingredients', []):
                    if not isinstance(ingredient, dict):
                        continue
                    ingredient_item = ingredient.get('item')
                    print(f"Found recipe {recipe_id} for item {item_id} with ingredient {ingredient_item}")

                    for ingredient_recipe in get_item_recipes(data, ingredient_item):
                        yield recipe_id
                        print(f"Recursively found recipe {ingredient_recipe} for ingredient {ingredient_item}")
                        yield ingredient_recipe
                break



def display_recipes(data, recipes):
    """Display the recipes in a readable format."""
    if not recipes:
        print("No recipes found.")
        return

    print("Recipes:")
    print("=" * 80)
    for recipe_id in recipes:
        recipe_data = data['recipes'].get(recipe_id, {})
        recipe_name = recipe_data.get('name', recipe_id)
        print(f"Recipe ID: {recipe_id} - {recipe_name}")
        print(f"  Machine: {recipe_data.get('machine', 'Unknown')}")
        print(f"  Time: {recipe_data.get('time', 1.0)} seconds")
        print(f"  Power Usage: {recipe_data.get('power_use', 0)} MW")
        print("  Products:")
        for product in recipe_data.get('products', []):
            item = product.get('item')
            amount = product.get('amount', 1)
            print(f"    - {item} x{amount}")
        print("  Ingredients:")
        for ingredient in recipe_data.get('ingredients', []):
            item = ingredient.get('item')
            amount = ingredient.get('amount', 1)
            print(f"    - {item} x{amount}")
        print()

def is_valid_item(data, item_id):
    """Check if an item ID is valid."""
    if item_id not in data.get('items', {}) and item_id not in data.get('resources', {}):
        print(f"Warning: Item '{item_id}' does not exist in the data!")
        return False
    return True

def is_resource(data, item_id):
    """Check if an item is a resource."""
    if not is_valid_item(data, item_id):
        return False
    return item_id in data.get('resources', {})

def is_crafted(data, item_id):
    """Check if an item is crafted by a recipe."""
    if not is_valid_item(data, item_id):
        return False
    if is_resource(data, item_id):
        return False
    for recipe_id, recipe_data in data['recipes'].items():
        if not recipe_data.get('products'):
            continue
        for product in recipe_data.get('products', []):
            if not isinstance(product, dict):
                continue
            product_item = product.get('item')
            if product_item == item_id:
                return True
    return False


def get_item_recipes(data,item_id):
    """Get all recipes that produce the given item."""
    recipes = []

    # First, validate that the item actually exists
    if item_id not in data.get('items', {}) and item_id not in data.get('resources', {}):
        print(f"Warning: Item '{item_id}' does not exist in the data!")
        return []

    if item_id in data.get('resources', {}):
        print(f"Item '{item_id}' is a resource, not a recipe product.")
        return []

    # Find recipes that produce this item
    for recipe_id, recipe_data in data['recipes'].items():
        if not recipe_data.get('products'):
            continue

        for product in recipe_data.get('products', []):
            if not isinstance(product, dict):
                continue

            product_item = product.get('item')
            if product_item == item_id:
                recipes.append(recipe_id)
                break

    return recipes

def display_recipe(recipe):
    print(f"{recipe.get('name', 'Unknown')}")
    #print(f"  Machine: {recipe.get('machine', 'Unknown')}, Time: {recipe.get('time', 1.0)} seconds")
    print("  Products:")
    for product in recipe.get('products', []):
        item = product.get('item')
        amount = product.get('amount', 1)
        print(f"    - {item} x{amount}")
    print("  Ingredients:")
    for ingredient in recipe.get('ingredients', []):
        item = ingredient.get('item')
        amount = ingredient.get('amount', 1)
        print(f"    - {item} x{amount}")

def build_recipe_tree(data, item_id, recipe_branch=None, recursion_level=0):
    if recursion_level > MAX_RECURSION_DEPTH:
        print(f"Max recursion depth reached for item {item_id}. Stopping recursion.")
        return False
    if not is_valid_item(data, item_id):
        return False
    if is_resource(data, item_id):
        return True
    for recipe_id in get_item_recipes(data, item_id):
        # Get the recipe for the recipe id
        recipe_data = data['recipes'].get(recipe_id, {})
        if "package" in recipe_id.lower():
            continue
        for ingredient in recipe_data.get('ingredients', []):
            if not isinstance(ingredient, dict):
                continue
            ingredient_item = ingredient.get('item')
            print(f"*** Look for ingredient {ingredient_item} in recipe {recipe_id} at level {recursion_level}***")
            if "Unpackaged" in ingredient_item.lower():
                continue
            #print(f"Found ingredient {ingredient_item} in recipe {recipe_id}")
            # Recursively build the tree for the ingredient
            if not build_recipe_tree(data, ingredient_item, recipe_branch, recursion_level=recursion_level + 1):
                break
            else:
                display_recipe(recipe_data)


def get_recipe(data, item_id, branches=[], branch={}, recursion_level=0):
    if recursion_level > MAX_RECURSION_DEPTH:
        print(f"Max recursion depth reached for item {item_id}. Stopping recursion.")
        return False
    if not is_valid_item(data, item_id):
        return False
    if is_resource(data, item_id):
        return True
    for recipe_id in get_item_recipes(data, item_id):
        # Get the recipe for the recipe id
        recipe_data = data['recipes'].get(recipe_id, {})
        if "package" in recipe_id.lower():
            continue
        branch = recipe_data
        for ingredient in recipe_data.get('ingredients', []):
            if not isinstance(ingredient, dict):
                continue
            ingredient_item = ingredient.get('item')
            print(f"*** Look for ingredient {ingredient_item} in recipe {recipe_id} at level {recursion_level}***")
            if "Unpackage" in ingredient_item.lower():
                continue
            #print(f"Found ingredient {ingredient_item} in recipe {recipe_id}")
            # Recursively build the tree for the ingredient
            if not get_recipe(data, ingredient_item, branches, branch, recursion_level=recursion_level + 1):
                break
            else:
                display_recipe(recipe_data)

# %%
data = load_data()
build_recipe_tree(data, 'Desc_SteelPipe_C')
# Out:
# *** Look for ingredient Desc_SteelIngot_C in recipe Recipe_SteelPipe_C at level 0***
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_IngotSteel_C at level 1***
# Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x3
#   Ingredients:
#     - Desc_OreIron_C x3
#     - Desc_Coal_C x3
# *** Look for ingredient Desc_Coal_C in recipe Recipe_IngotSteel_C at level 1***
# Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x3
#   Ingredients:
#     - Desc_OreIron_C x3
#     - Desc_Coal_C x3
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_CokeSteelIngot_C at level 1***
# Alternate: Coke Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x20
#   Ingredients:
#     - Desc_OreIron_C x15
#     - Desc_PetroleumCoke_C x15
# *** Look for ingredient Desc_PetroleumCoke_C in recipe Recipe_Alternate_CokeSteelIngot_C at level 1***
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_PetroleumCoke_C at level 2***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 3***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 3***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 3***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 3***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IngotSteel_2_C at level 1***
# Alternate: Compacted Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x4
#   Ingredients:
#     - Desc_OreIron_C x2
#     - Desc_CompactedCoal_C x1
# *** Look for ingredient Desc_CompactedCoal_C in recipe Recipe_Alternate_IngotSteel_2_C at level 1***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_RocketFuel_Nitro_C at level 2***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 3***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 4***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 4***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 4***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 4***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 4***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 4***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidTurboFuel_C in recipe Recipe_RocketFuel_C at level 2***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_Turbofuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 4***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_TurboHeavyFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 4***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 4***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 4***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_TurboBlendFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 4***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_PackagedRocketFuel_C in recipe Recipe_Alternate_IonizedFuel_Dark_C at level 2***
# *** Look for ingredient Desc_RocketFuel_C in recipe Recipe_IonizedFuel_C at level 2***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_RocketFuel_Nitro_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 4***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidTurboFuel_C in recipe Recipe_RocketFuel_C at level 3***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_Turbofuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 5***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_TurboHeavyFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_TurboBlendFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 5***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_Coal_C in recipe Recipe_Alternate_EnrichedCoal_C at level 2***
# Alternate: Compacted Coal
#   Products:
#     - Desc_CompactedCoal_C x5
#   Ingredients:
#     - Desc_Coal_C x5
#     - Desc_Sulfur_C x5
# *** Look for ingredient Desc_Sulfur_C in recipe Recipe_Alternate_EnrichedCoal_C at level 2***
# Alternate: Compacted Coal
#   Products:
#     - Desc_CompactedCoal_C x5
#   Ingredients:
#     - Desc_Coal_C x5
#     - Desc_Sulfur_C x5
# *** Look for ingredient Desc_IronIngot_C in recipe Recipe_Alternate_IngotSteel_1_C at level 1***
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_IngotIron_C at level 2***
# Iron Ingot
#   Products:
#     - Desc_IronIngot_C x1
#   Ingredients:
#     - Desc_OreIron_C x1
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_PureIronIngot_C at level 2***
# Alternate: Pure Iron Ingot
#   Products:
#     - Desc_IronIngot_C x13
#   Ingredients:
#     - Desc_OreIron_C x7
#     - Desc_Water_C x4.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_Alternate_PureIronIngot_C at level 2***
# Alternate: Pure Iron Ingot
#   Products:
#     - Desc_IronIngot_C x13
#   Ingredients:
#     - Desc_OreIron_C x7
#     - Desc_Water_C x4.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IronIngot_Leached_C at level 2***
# Alternate: Leached Iron ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_SulfuricAcid_C x1.0
# *** Look for ingredient Desc_SulfuricAcid_C in recipe Recipe_Alternate_IronIngot_Leached_C at level 2***
# *** Look for ingredient Desc_OreUranium_C in recipe Recipe_UraniumCell_C at level 3***
# Encased Uranium Cell
#   Products:
#     - Desc_UraniumCell_C x5
#     - Desc_SulfuricAcid_C x2.0
#   Ingredients:
#     - Desc_OreUranium_C x10
#     - Desc_Cement_C x3
#     - Desc_SulfuricAcid_C x8.0
# *** Look for ingredient Desc_Cement_C in recipe Recipe_UraniumCell_C at level 3***
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_WetConcrete_C at level 4***
# Alternate: Wet Concrete
#   Products:
#     - Desc_Cement_C x4
#   Ingredients:
#     - Desc_Stone_C x6
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_Alternate_WetConcrete_C at level 4***
# Alternate: Wet Concrete
#   Products:
#     - Desc_Cement_C x4
#   Ingredients:
#     - Desc_Stone_C x6
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_RubberConcrete_C at level 4***
# Alternate: Rubber Concrete
#   Products:
#     - Desc_Cement_C x9
#   Ingredients:
#     - Desc_Stone_C x10
#     - Desc_Rubber_C x2
# *** Look for ingredient Desc_Rubber_C in recipe Recipe_Alternate_RubberConcrete_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualRubber_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_Plastic_C in recipe Recipe_Alternate_RecycledRubber_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualPlastic_C at level 6***
# Max recursion depth reached for item Desc_PolymerResin_C. Stopping recursion.
# *** Look for ingredient Desc_Rubber_C in recipe Recipe_Alternate_Plastic_1_C at level 6***
# Max recursion depth reached for item Desc_Rubber_C. Stopping recursion.
# *** Look for ingredient Desc_Silica_C in recipe Recipe_Alternate_Concrete_C at level 4***
# *** Look for ingredient Desc_OreBauxite_C in recipe Recipe_AluminaSolution_C at level 5***
# Alumina Solution
#   Products:
#     - Desc_AluminaSolution_C x12.0
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_OreBauxite_C x12
#     - Desc_Water_C x18.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_AluminaSolution_C at level 5***
# Alumina Solution
#   Products:
#     - Desc_AluminaSolution_C x12.0
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_OreBauxite_C x12
#     - Desc_Water_C x18.0
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Silica_C at level 5***
# Silica
#   Products:
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_RawQuartz_C x3
# *** Look for ingredient Desc_DissolvedSilica_C in recipe Recipe_Alternate_Silica_Distilled_C at level 5***
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Alternate_Quartz_Purified_C at level 6***
# Max recursion depth reached for item Desc_RawQuartz_C. Stopping recursion.
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Alternate_Silica_C at level 5***
# Alternate: Cheap Silica
#   Products:
#     - Desc_Silica_C x7
#   Ingredients:
#     - Desc_RawQuartz_C x3
#     - Desc_Stone_C x5
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_Silica_C at level 5***
# Alternate: Cheap Silica
#   Products:
#     - Desc_Silica_C x7
#   Ingredients:
#     - Desc_RawQuartz_C x3
#     - Desc_Stone_C x5
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Concrete_C at level 4***
# Concrete
#   Products:
#     - Desc_Cement_C x1
#   Ingredients:
#     - Desc_Stone_C x3
# *** Look for ingredient Desc_Sulfur_C in recipe Recipe_SulfuricAcid_C at level 3***
# Sulfuric Acid
#   Products:
#     - Desc_SulfuricAcid_C x5.0
#   Ingredients:
#     - Desc_Sulfur_C x5
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_SulfuricAcid_C at level 3***
# Sulfuric Acid
#   Products:
#     - Desc_SulfuricAcid_C x5.0
#   Ingredients:
#     - Desc_Sulfur_C x5
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IronIngot_Basic_C at level 2***
# Alternate: Basic Iron Ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_Stone_C x8
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_IronIngot_Basic_C at level 2***
# Alternate: Basic Iron Ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_Stone_C x8
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IngotIron_C at level 2***
# Alternate: Iron Alloy Ingot
#   Products:
#     - Desc_IronIngot_C x15
#   Ingredients:
#     - Desc_OreIron_C x8
#     - Desc_OreCopper_C x2
# *** Look for ingredient Desc_OreCopper_C in recipe Recipe_Alternate_IngotIron_C at level 2***
# Alternate: Iron Alloy Ingot
#   Products:
#     - Desc_IronIngot_C x15
#   Ingredients:
#     - Desc_OreIron_C x8
#     - Desc_OreCopper_C x2
# *** Look for ingredient Desc_SteelIngot_C in recipe Recipe_Alternate_SteelPipe_Molded_C at level 0***
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_IngotSteel_C at level 1***
# Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x3
#   Ingredients:
#     - Desc_OreIron_C x3
#     - Desc_Coal_C x3
# *** Look for ingredient Desc_Coal_C in recipe Recipe_IngotSteel_C at level 1***
# Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x3
#   Ingredients:
#     - Desc_OreIron_C x3
#     - Desc_Coal_C x3
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_CokeSteelIngot_C at level 1***
# Alternate: Coke Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x20
#   Ingredients:
#     - Desc_OreIron_C x15
#     - Desc_PetroleumCoke_C x15
# *** Look for ingredient Desc_PetroleumCoke_C in recipe Recipe_Alternate_CokeSteelIngot_C at level 1***
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_PetroleumCoke_C at level 2***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 3***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 3***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 3***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 3***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IngotSteel_2_C at level 1***
# Alternate: Compacted Steel Ingot
#   Products:
#     - Desc_SteelIngot_C x4
#   Ingredients:
#     - Desc_OreIron_C x2
#     - Desc_CompactedCoal_C x1
# *** Look for ingredient Desc_CompactedCoal_C in recipe Recipe_Alternate_IngotSteel_2_C at level 1***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_RocketFuel_Nitro_C at level 2***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 3***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 4***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 4***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 4***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 4***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 4***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 4***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidTurboFuel_C in recipe Recipe_RocketFuel_C at level 2***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_Turbofuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 4***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_TurboHeavyFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 4***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 4***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 4***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_TurboBlendFuel_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 4***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_PackagedRocketFuel_C in recipe Recipe_Alternate_IonizedFuel_Dark_C at level 2***
# *** Look for ingredient Desc_RocketFuel_C in recipe Recipe_IonizedFuel_C at level 2***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_RocketFuel_Nitro_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 4***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidTurboFuel_C in recipe Recipe_RocketFuel_C at level 3***
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_Turbofuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 5***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_TurboHeavyFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_LiquidFuel_C in recipe Recipe_Alternate_TurboBlendFuel_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 5***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_ResidualFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_HeavyOilResidue_C in recipe Recipe_Alternate_DilutedFuel_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_Coal_C in recipe Recipe_Alternate_EnrichedCoal_C at level 2***
# Alternate: Compacted Coal
#   Products:
#     - Desc_CompactedCoal_C x5
#   Ingredients:
#     - Desc_Coal_C x5
#     - Desc_Sulfur_C x5
# *** Look for ingredient Desc_Sulfur_C in recipe Recipe_Alternate_EnrichedCoal_C at level 2***
# Alternate: Compacted Coal
#   Products:
#     - Desc_CompactedCoal_C x5
#   Ingredients:
#     - Desc_Coal_C x5
#     - Desc_Sulfur_C x5
# *** Look for ingredient Desc_IronIngot_C in recipe Recipe_Alternate_IngotSteel_1_C at level 1***
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_IngotIron_C at level 2***
# Iron Ingot
#   Products:
#     - Desc_IronIngot_C x1
#   Ingredients:
#     - Desc_OreIron_C x1
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_PureIronIngot_C at level 2***
# Alternate: Pure Iron Ingot
#   Products:
#     - Desc_IronIngot_C x13
#   Ingredients:
#     - Desc_OreIron_C x7
#     - Desc_Water_C x4.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_Alternate_PureIronIngot_C at level 2***
# Alternate: Pure Iron Ingot
#   Products:
#     - Desc_IronIngot_C x13
#   Ingredients:
#     - Desc_OreIron_C x7
#     - Desc_Water_C x4.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IronIngot_Leached_C at level 2***
# Alternate: Leached Iron ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_SulfuricAcid_C x1.0
# *** Look for ingredient Desc_SulfuricAcid_C in recipe Recipe_Alternate_IronIngot_Leached_C at level 2***
# *** Look for ingredient Desc_OreUranium_C in recipe Recipe_UraniumCell_C at level 3***
# Encased Uranium Cell
#   Products:
#     - Desc_UraniumCell_C x5
#     - Desc_SulfuricAcid_C x2.0
#   Ingredients:
#     - Desc_OreUranium_C x10
#     - Desc_Cement_C x3
#     - Desc_SulfuricAcid_C x8.0
# *** Look for ingredient Desc_Cement_C in recipe Recipe_UraniumCell_C at level 3***
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_WetConcrete_C at level 4***
# Alternate: Wet Concrete
#   Products:
#     - Desc_Cement_C x4
#   Ingredients:
#     - Desc_Stone_C x6
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_Alternate_WetConcrete_C at level 4***
# Alternate: Wet Concrete
#   Products:
#     - Desc_Cement_C x4
#   Ingredients:
#     - Desc_Stone_C x6
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_RubberConcrete_C at level 4***
# Alternate: Rubber Concrete
#   Products:
#     - Desc_Cement_C x9
#   Ingredients:
#     - Desc_Stone_C x10
#     - Desc_Rubber_C x2
# *** Look for ingredient Desc_Rubber_C in recipe Recipe_Alternate_RubberConcrete_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 5***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualRubber_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_Plastic_C in recipe Recipe_Alternate_RecycledRubber_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualPlastic_C at level 6***
# Max recursion depth reached for item Desc_PolymerResin_C. Stopping recursion.
# *** Look for ingredient Desc_Rubber_C in recipe Recipe_Alternate_Plastic_1_C at level 6***
# Max recursion depth reached for item Desc_Rubber_C. Stopping recursion.
# *** Look for ingredient Desc_Silica_C in recipe Recipe_Alternate_Concrete_C at level 4***
# *** Look for ingredient Desc_OreBauxite_C in recipe Recipe_AluminaSolution_C at level 5***
# Alumina Solution
#   Products:
#     - Desc_AluminaSolution_C x12.0
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_OreBauxite_C x12
#     - Desc_Water_C x18.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_AluminaSolution_C at level 5***
# Alumina Solution
#   Products:
#     - Desc_AluminaSolution_C x12.0
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_OreBauxite_C x12
#     - Desc_Water_C x18.0
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Silica_C at level 5***
# Silica
#   Products:
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_RawQuartz_C x3
# *** Look for ingredient Desc_DissolvedSilica_C in recipe Recipe_Alternate_Silica_Distilled_C at level 5***
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Alternate_Quartz_Purified_C at level 6***
# Max recursion depth reached for item Desc_RawQuartz_C. Stopping recursion.
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Alternate_Silica_C at level 5***
# Alternate: Cheap Silica
#   Products:
#     - Desc_Silica_C x7
#   Ingredients:
#     - Desc_RawQuartz_C x3
#     - Desc_Stone_C x5
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_Silica_C at level 5***
# Alternate: Cheap Silica
#   Products:
#     - Desc_Silica_C x7
#   Ingredients:
#     - Desc_RawQuartz_C x3
#     - Desc_Stone_C x5
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Concrete_C at level 4***
# Concrete
#   Products:
#     - Desc_Cement_C x1
#   Ingredients:
#     - Desc_Stone_C x3
# *** Look for ingredient Desc_Sulfur_C in recipe Recipe_SulfuricAcid_C at level 3***
# Sulfuric Acid
#   Products:
#     - Desc_SulfuricAcid_C x5.0
#   Ingredients:
#     - Desc_Sulfur_C x5
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_SulfuricAcid_C at level 3***
# Sulfuric Acid
#   Products:
#     - Desc_SulfuricAcid_C x5.0
#   Ingredients:
#     - Desc_Sulfur_C x5
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IronIngot_Basic_C at level 2***
# Alternate: Basic Iron Ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_Stone_C x8
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_IronIngot_Basic_C at level 2***
# Alternate: Basic Iron Ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_Stone_C x8
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IngotIron_C at level 2***
# Alternate: Iron Alloy Ingot
#   Products:
#     - Desc_IronIngot_C x15
#   Ingredients:
#     - Desc_OreIron_C x8
#     - Desc_OreCopper_C x2
# *** Look for ingredient Desc_OreCopper_C in recipe Recipe_Alternate_IngotIron_C at level 2***
# Alternate: Iron Alloy Ingot
#   Products:
#     - Desc_IronIngot_C x15
#   Ingredients:
#     - Desc_OreIron_C x8
#     - Desc_OreCopper_C x2
# *** Look for ingredient Desc_IronIngot_C in recipe Recipe_Alternate_SteelPipe_Iron_C at level 0***
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_IngotIron_C at level 1***
# Iron Ingot
#   Products:
#     - Desc_IronIngot_C x1
#   Ingredients:
#     - Desc_OreIron_C x1
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_PureIronIngot_C at level 1***
# Alternate: Pure Iron Ingot
#   Products:
#     - Desc_IronIngot_C x13
#   Ingredients:
#     - Desc_OreIron_C x7
#     - Desc_Water_C x4.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_Alternate_PureIronIngot_C at level 1***
# Alternate: Pure Iron Ingot
#   Products:
#     - Desc_IronIngot_C x13
#   Ingredients:
#     - Desc_OreIron_C x7
#     - Desc_Water_C x4.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IronIngot_Leached_C at level 1***
# Alternate: Leached Iron ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_SulfuricAcid_C x1.0
# *** Look for ingredient Desc_SulfuricAcid_C in recipe Recipe_Alternate_IronIngot_Leached_C at level 1***
# *** Look for ingredient Desc_OreUranium_C in recipe Recipe_UraniumCell_C at level 2***
# Encased Uranium Cell
#   Products:
#     - Desc_UraniumCell_C x5
#     - Desc_SulfuricAcid_C x2.0
#   Ingredients:
#     - Desc_OreUranium_C x10
#     - Desc_Cement_C x3
#     - Desc_SulfuricAcid_C x8.0
# *** Look for ingredient Desc_Cement_C in recipe Recipe_UraniumCell_C at level 2***
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_WetConcrete_C at level 3***
# Alternate: Wet Concrete
#   Products:
#     - Desc_Cement_C x4
#   Ingredients:
#     - Desc_Stone_C x6
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_Alternate_WetConcrete_C at level 3***
# Alternate: Wet Concrete
#   Products:
#     - Desc_Cement_C x4
#   Ingredients:
#     - Desc_Stone_C x6
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_RubberConcrete_C at level 3***
# Alternate: Rubber Concrete
#   Products:
#     - Desc_Cement_C x9
#   Ingredients:
#     - Desc_Stone_C x10
#     - Desc_Rubber_C x2
# *** Look for ingredient Desc_Rubber_C in recipe Recipe_Alternate_RubberConcrete_C at level 3***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 4***
# Rubber
#   Products:
#     - Desc_Rubber_C x2
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualRubber_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 5***
# Fuel
#   Products:
#     - Desc_LiquidFuel_C x4.0
#     - Desc_PolymerResin_C x3
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 5***
# Alternate: Polymer Resin
#   Products:
#     - Desc_PolymerResin_C x13
#     - Desc_HeavyOilResidue_C x2.0
#   Ingredients:
#     - Desc_LiquidOil_C x6.0
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 5***
# Alternate: Heavy Oil Residue
#   Products:
#     - Desc_HeavyOilResidue_C x4.0
#     - Desc_PolymerResin_C x2
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_Plastic_C in recipe Recipe_Alternate_RecycledRubber_C at level 4***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Plastic_C at level 5***
# Plastic
#   Products:
#     - Desc_Plastic_C x2
#     - Desc_HeavyOilResidue_C x1.0
#   Ingredients:
#     - Desc_LiquidOil_C x3.0
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualPlastic_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_LiquidFuel_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_PolymerResin_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Alternate_HeavyOilResidue_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_Rubber_C in recipe Recipe_Alternate_Plastic_1_C at level 5***
# *** Look for ingredient Desc_LiquidOil_C in recipe Recipe_Rubber_C at level 6***
# Max recursion depth reached for item Desc_LiquidOil_C. Stopping recursion.
# *** Look for ingredient Desc_PolymerResin_C in recipe Recipe_ResidualRubber_C at level 6***
# Max recursion depth reached for item Desc_PolymerResin_C. Stopping recursion.
# *** Look for ingredient Desc_Plastic_C in recipe Recipe_Alternate_RecycledRubber_C at level 6***
# Max recursion depth reached for item Desc_Plastic_C. Stopping recursion.
# *** Look for ingredient Desc_Silica_C in recipe Recipe_Alternate_Concrete_C at level 3***
# *** Look for ingredient Desc_OreBauxite_C in recipe Recipe_AluminaSolution_C at level 4***
# Alumina Solution
#   Products:
#     - Desc_AluminaSolution_C x12.0
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_OreBauxite_C x12
#     - Desc_Water_C x18.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_AluminaSolution_C at level 4***
# Alumina Solution
#   Products:
#     - Desc_AluminaSolution_C x12.0
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_OreBauxite_C x12
#     - Desc_Water_C x18.0
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Silica_C at level 4***
# Silica
#   Products:
#     - Desc_Silica_C x5
#   Ingredients:
#     - Desc_RawQuartz_C x3
# *** Look for ingredient Desc_DissolvedSilica_C in recipe Recipe_Alternate_Silica_Distilled_C at level 4***
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Alternate_Quartz_Purified_C at level 5***
# Alternate: Quartz Purification
#   Products:
#     - Desc_QuartzCrystal_C x15
#     - Desc_DissolvedSilica_C x12.0
#   Ingredients:
#     - Desc_RawQuartz_C x24
#     - Desc_NitricAcid_C x2.0
# *** Look for ingredient Desc_NitricAcid_C in recipe Recipe_Alternate_Quartz_Purified_C at level 5***
# *** Look for ingredient Desc_NitrogenGas_C in recipe Recipe_NitricAcid_C at level 6***
# Max recursion depth reached for item Desc_NitrogenGas_C. Stopping recursion.
# *** Look for ingredient Desc_RawQuartz_C in recipe Recipe_Alternate_Silica_C at level 4***
# Alternate: Cheap Silica
#   Products:
#     - Desc_Silica_C x7
#   Ingredients:
#     - Desc_RawQuartz_C x3
#     - Desc_Stone_C x5
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_Silica_C at level 4***
# Alternate: Cheap Silica
#   Products:
#     - Desc_Silica_C x7
#   Ingredients:
#     - Desc_RawQuartz_C x3
#     - Desc_Stone_C x5
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Concrete_C at level 3***
# Concrete
#   Products:
#     - Desc_Cement_C x1
#   Ingredients:
#     - Desc_Stone_C x3
# *** Look for ingredient Desc_Sulfur_C in recipe Recipe_SulfuricAcid_C at level 2***
# Sulfuric Acid
#   Products:
#     - Desc_SulfuricAcid_C x5.0
#   Ingredients:
#     - Desc_Sulfur_C x5
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_Water_C in recipe Recipe_SulfuricAcid_C at level 2***
# Sulfuric Acid
#   Products:
#     - Desc_SulfuricAcid_C x5.0
#   Ingredients:
#     - Desc_Sulfur_C x5
#     - Desc_Water_C x5.0
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IronIngot_Basic_C at level 1***
# Alternate: Basic Iron Ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_Stone_C x8
# *** Look for ingredient Desc_Stone_C in recipe Recipe_Alternate_IronIngot_Basic_C at level 1***
# Alternate: Basic Iron Ingot
#   Products:
#     - Desc_IronIngot_C x10
#   Ingredients:
#     - Desc_OreIron_C x5
#     - Desc_Stone_C x8
# *** Look for ingredient Desc_OreIron_C in recipe Recipe_Alternate_IngotIron_C at level 1***
# Alternate: Iron Alloy Ingot
#   Products:
#     - Desc_IronIngot_C x15
#   Ingredients:
#     - Desc_OreIron_C x8
#     - Desc_OreCopper_C x2
# *** Look for ingredient Desc_OreCopper_C in recipe Recipe_Alternate_IngotIron_C at level 1***
# Alternate: Iron Alloy Ingot
#   Products:
#     - Desc_IronIngot_C x15
#   Ingredients:
#     - Desc_OreIron_C x8
#     - Desc_OreCopper_C x2
